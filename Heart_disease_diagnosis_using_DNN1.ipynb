# %% [markdown]
# <a href="https://colab.research.google.com/github/nanda3-vit/AI-and-ML-for-Cardiovascular-diseases-CVDs-/blob/main/Heart_disease_diagnosis_using_DNN1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heart Disease Prediction using Deep Neural Networks
# **Dataset - Cleveland**

# %%
# !pip install tensorflow-gpu==2.0.0-alpha0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu==2.0.0-alpha0 (from versions: 1.13.1, 1.13.2, 1.14.0, 1.15.0, 1.15.2, 1.15.3, 1.15.4, 1.15.5, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.0.4, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.3.0, 2.3.1, 2.3.2, 2.3.3, 2.3.4, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.4.4, 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1)
# ERROR: No matching distribution found for tensorflow-gpu==2.0.0-alpha0

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from google.colab import drive
from sklearn.model_selection import train_test_split


# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)

# %%
heart_csv_path = "/content/sample_data/2.1heart_cleveland_upload.csv"

# %%
data = pd.read_csv(heart_csv_path)

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    2.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    0.602694    0.676768
# std      0.994914   22.941562    0.469761    1.166123    0.618187    0.938965
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    1.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    3.000000
#
#              thal   condition
# count  297.000000  297.000000
# mean     0.835017    0.461279
# std      0.956690    0.499340
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      2.000000    1.000000
# max      2.000000    1.000000

# %%
data.shape
# Out:
# (297, 14)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'condition'],
#       dtype='object')

# %%
f = sns.countplot(x='condition', data=data)
f.set_title("Heart disease presence distribution")
f.set_xticklabels(['No Heart disease', 'Heart Disease'])
plt.xlabel("");

# %%
f = sns.countplot(x='condition', data=data, hue='sex')
plt.legend(['Female', 'Male'])
f.set_title("Heart disease presence by gender")
f.set_xticklabels(['No Heart disease', 'Heart Disease'])
plt.xlabel("");

# %%
heat_map = sns.heatmap(data.corr(method='pearson'), annot=True, fmt='.2f', linewidths=2)
heat_map.set_xticklabels(heat_map.get_xticklabels(), rotation=45);

# %%
plt.scatter(x=data.age[data.condition==1], y=data.thalach[(data.condition==1)], c="red", s=60)
plt.scatter(x=data.age[data.condition==0], y=data.thalach[(data.condition==0)], s=60)
plt.legend(["Disease", "No Disease"])
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate");

# %%
data['Age_Category'] = pd.cut(data['age'],bins=list(np.arange(25, 85, 5)))

# %%
plt.subplot(121)
data[data['condition']==1].groupby('Age_Category')['age'].count().plot(kind='bar')
plt.title('Age Distribution of Patients with +ve Heart Diagonsis')

plt.subplot(122)
data[data['condition']==0].groupby('Age_Category')['age'].count().plot(kind='bar')
plt.title('Age Distribution of Patients with -ve Heart Diagonsis')
# Out:
# Text(0.5, 1.0, 'Age Distribution of Patients with -ve Heart Diagonsis')

# %%
del data['Age_Category']

# %%
f = sns.countplot(x='cp', data=data, hue='condition')
f.set_xticklabels(['Typical Angina', 'Atypical Angina', 'Non-anginal Pain', 'Asymptomatic']);
f.set_title('Disease presence by chest pain type')
plt.ylabel('Chest Pain Type')
plt.xlabel('')
plt.legend(['No Disease', 'Disease']);

# %%
X = data.loc[:,data.columns!='condition']
y = data.iloc[:,-1]

# %%
data.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalach      0
# exang        0
# oldpeak      0
# slope        0
# ca           0
# thal         0
# condition    0
# dtype: int64

# %%
feature_columns = []

# numeric cols
for header in ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'ca']:
  feature_columns.append(tf.feature_column.numeric_column(header))

# bucketized cols
age = tf.feature_column.numeric_column("age")
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[18, 25, 30, 35, 40, 45, 50, 55, 60, 65])
feature_columns.append(age_buckets)

# indicator cols
data["thal"] = data["thal"].apply(str)
thal = tf.feature_column.categorical_column_with_vocabulary_list(
      'thal', ['3', '6', '7'])
thal_one_hot = tf.feature_column.indicator_column(thal)
feature_columns.append(thal_one_hot)

data["sex"] = data["sex"].apply(str)
sex = tf.feature_column.categorical_column_with_vocabulary_list(
      'sex', ['0', '1'])
sex_one_hot = tf.feature_column.indicator_column(sex)
feature_columns.append(sex_one_hot)

data["cp"] = data["cp"].apply(str)
cp = tf.feature_column.categorical_column_with_vocabulary_list(
      'cp', ['0', '1', '2', '3'])
cp_one_hot = tf.feature_column.indicator_column(cp)
feature_columns.append(cp_one_hot)

data["slope"] = data["slope"].apply(str)
slope = tf.feature_column.categorical_column_with_vocabulary_list(
      'slope', ['0', '1', '2'])
slope_one_hot = tf.feature_column.indicator_column(slope)
feature_columns.append(slope_one_hot)


# embedding cols
thal_embedding = tf.feature_column.embedding_column(thal, dimension=8)
feature_columns.append(thal_embedding)

# crossed cols
age_thal_crossed = tf.feature_column.crossed_column([age_buckets, thal], hash_bucket_size=1000)
age_thal_crossed = tf.feature_column.indicator_column(age_thal_crossed)
feature_columns.append(age_thal_crossed)

cp_slope_crossed = tf.feature_column.crossed_column([cp, slope], hash_bucket_size=1000)
cp_slope_crossed = tf.feature_column.indicator_column(cp_slope_crossed)
feature_columns.append(cp_slope_crossed)

# %%
def create_dataset(dataframe, batch_size=32):
  dataframe = dataframe.copy()
  labels = dataframe.pop('condition')
  return tf.data.Dataset.from_tensor_slices((dict(dataframe), labels)) \
          .shuffle(buffer_size=len(dataframe)) \
          .batch(batch_size)

# %%
train, test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)

# %%
train_ds = create_dataset(train)
test_ds = create_dataset(test)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.DenseFeatures(feature_columns=feature_columns),
  tf.keras.layers.Dense(units=128, activation='relu'),
  tf.keras.layers.Dropout(rate=0.2),
  tf.keras.layers.Dense(units=128, activation='relu'),
  tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_ds, validation_data=test_ds, epochs=100, use_multiprocessing=True)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'age': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=int64>, 'sex': <tf.Tensor 'IteratorGetNext:8' shape=(None,) dtype=string>, 'cp': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=string>, 'trestbps': <tf.Tensor 'IteratorGetNext:12' shape=(None,) dtype=int64>, 'chol': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=int64>, 'fbs': <tf.Tensor 'IteratorGetNext:5' shape=(None,) dtype=int64>, 'restecg': <tf.Tensor 'IteratorGetNext:7' shape=(None,) dtype=int64>, 'thalach': <tf.Tensor 'IteratorGetNext:11' shape=(None,) dtype=int64>, 'exang': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=int64>, 'oldpeak': <tf.Tensor 'IteratorGetNext:6' shape=(None,) dtype=float64>, 'slope': <tf.Tensor 'IteratorGetNext:9' shape=(None,) dtype=string>, 'ca': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=int64>, 'thal': <tf.Tensor 'IteratorGetNext:10' shape=(None,) dtype=string>}. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'age': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=int64>, 'sex': <tf.Tensor 'IteratorGetNext:8' shape=(None,) dtype=string>, 'cp': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=string>, 'trestbps': <tf.Tensor 'IteratorGetNext:12' shape=(None,) dtype=int64>, 'chol': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=int64>, 'fbs': <tf.Tensor 'IteratorGetNext:5' shape=(None,) dtype=int64>, 'restecg': <tf.Tensor 'IteratorGetNext:7' shape=(None,) dtype=int64>, 'thalach': <tf.Tensor 'IteratorGetNext:11' shape=(None,) dtype=int64>, 'exang': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=int64>, 'oldpeak': <tf.Tensor 'IteratorGetNext:6' shape=(None,) dtype=float64>, 'slope': <tf.Tensor 'IteratorGetNext:9' shape=(None,) dtype=string>, 'ca': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=int64>, 'thal': <tf.Tensor 'IteratorGetNext:10' shape=(None,) dtype=string>}. Consider rewriting this model with the Functional API.
# 7/8 [=========================>....] - ETA: 0s - loss: 2.0938 - accuracy: 0.5580 WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs={'age': <tf.Tensor 'IteratorGetNext:0' shape=(None,) dtype=int64>, 'sex': <tf.Tensor 'IteratorGetNext:8' shape=(None,) dtype=string>, 'cp': <tf.Tensor 'IteratorGetNext:3' shape=(None,) dtype=string>, 'trestbps': <tf.Tensor 'IteratorGetNext:12' shape=(None,) dtype=int64>, 'chol': <tf.Tensor 'IteratorGetNext:2' shape=(None,) dtype=int64>, 'fbs': <tf.Tensor 'IteratorGetNext:5' shape=(None,) dtype=int64>, 'restecg': <tf.Tensor 'IteratorGetNext:7' shape=(None,) dtype=int64>, 'thalach': <tf.Tensor 'IteratorGetNext:11' shape=(None,) dtype=int64>, 'exang': <tf.Tensor 'IteratorGetNext:4' shape=(None,) dtype=int64>, 'oldpeak': <tf.Tensor 'IteratorGetNext:6' shape=(None,) dtype=float64>, 'slope': <tf.Tensor 'IteratorGetNext:9' shape=(None,) dtype=string>, 'ca': <tf.Tensor 'IteratorGetNext:1' shape=(None,) dtype=int64>, 'thal': <tf.Tensor 'IteratorGetNext:10' shape=(None,) dtype=string>}. Consider rewriting this model with the Functional API.
# 8/8 [==============================] - 3s 85ms/step - loss: 2.0945 - accuracy: 0.5527 - val_loss: 0.9749 - val_accuracy: 0.5000
# Epoch 2/100
# 8/8 [==============================] - 0s 9ms/step - loss: 1.2658 - accuracy: 0.5907 - val_loss: 0.8591 - val_accuracy: 0.5167
# Epoch 3/100
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0179 - accuracy: 0.6329 - val_loss: 1.0453 - val_accuracy: 0.5833
# Epoch 4/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.9409 - accuracy: 0.6329 - val_loss: 0.7378 - val_accuracy: 0.5167
# Epoch 5/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7703 - accuracy: 0.6793 - val_loss: 0.7059 - val_accuracy: 0.5667
# Epoch 6/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7778 - accuracy: 0.6624 - val_loss: 0.7003 - val_accuracy: 0.5833
# Epoch 7/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6542 - accuracy: 0.6962 - val_loss: 0.6655 - val_accuracy: 0.6000
# Epoch 8/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.6350 - accuracy: 0.7089 - val_loss: 0.6830 - val_accuracy: 0.5667
# Epoch 9/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6224 - accuracy: 0.6878 - val_loss: 0.9563 - val_accuracy: 0.5833
# Epoch 10/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.7164 - accuracy: 0.6203 - val_loss: 0.7735 - val_accuracy: 0.5833
# Epoch 11/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6186 - accuracy: 0.7089 - val_loss: 0.8359 - val_accuracy: 0.6167
# Epoch 12/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.7892 - accuracy: 0.6498 - val_loss: 0.6806 - val_accuracy: 0.6000
# Epoch 13/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6634 - accuracy: 0.6709 - val_loss: 0.9443 - val_accuracy: 0.5500
# Epoch 14/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6152 - accuracy: 0.6835 - val_loss: 0.6671 - val_accuracy: 0.6833
# Epoch 15/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5342 - accuracy: 0.7595 - val_loss: 0.6943 - val_accuracy: 0.5833
# Epoch 16/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5519 - accuracy: 0.7257 - val_loss: 0.6956 - val_accuracy: 0.5667
# Epoch 17/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5175 - accuracy: 0.7679 - val_loss: 0.6750 - val_accuracy: 0.5833
# Epoch 18/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5425 - accuracy: 0.7384 - val_loss: 0.6475 - val_accuracy: 0.6000
# Epoch 19/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5051 - accuracy: 0.7426 - val_loss: 0.6247 - val_accuracy: 0.7000
# Epoch 20/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4832 - accuracy: 0.7679 - val_loss: 0.6945 - val_accuracy: 0.6000
# Epoch 21/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5308 - accuracy: 0.7004 - val_loss: 0.7791 - val_accuracy: 0.6333
# Epoch 22/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5887 - accuracy: 0.6962 - val_loss: 0.6735 - val_accuracy: 0.6500
# Epoch 23/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5560 - accuracy: 0.7342 - val_loss: 0.6401 - val_accuracy: 0.6000
# Epoch 24/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4871 - accuracy: 0.7975 - val_loss: 0.6407 - val_accuracy: 0.5833
# Epoch 25/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4313 - accuracy: 0.7890 - val_loss: 0.6135 - val_accuracy: 0.6833
# Epoch 26/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5037 - accuracy: 0.7637 - val_loss: 0.6770 - val_accuracy: 0.5667
# Epoch 27/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4673 - accuracy: 0.7975 - val_loss: 0.6132 - val_accuracy: 0.6500
# Epoch 28/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4670 - accuracy: 0.7679 - val_loss: 0.6271 - val_accuracy: 0.7167
# Epoch 29/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4724 - accuracy: 0.8143 - val_loss: 0.6268 - val_accuracy: 0.6500
# Epoch 30/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4350 - accuracy: 0.7975 - val_loss: 0.6357 - val_accuracy: 0.7167
# Epoch 31/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5341 - accuracy: 0.7173 - val_loss: 0.6603 - val_accuracy: 0.7000
# Epoch 32/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5646 - accuracy: 0.7468 - val_loss: 0.6018 - val_accuracy: 0.6667
# Epoch 33/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4327 - accuracy: 0.7932 - val_loss: 0.5947 - val_accuracy: 0.7000
# Epoch 34/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4255 - accuracy: 0.7975 - val_loss: 0.5707 - val_accuracy: 0.7167
# Epoch 35/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4036 - accuracy: 0.8059 - val_loss: 0.5557 - val_accuracy: 0.7167
# Epoch 36/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4246 - accuracy: 0.8143 - val_loss: 0.8588 - val_accuracy: 0.6000
# Epoch 37/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5627 - accuracy: 0.7257 - val_loss: 0.6487 - val_accuracy: 0.7167
# Epoch 38/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4708 - accuracy: 0.7848 - val_loss: 0.6177 - val_accuracy: 0.6833
# Epoch 39/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3868 - accuracy: 0.8397 - val_loss: 0.6138 - val_accuracy: 0.7000
# Epoch 40/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3965 - accuracy: 0.8354 - val_loss: 0.6112 - val_accuracy: 0.7167
# Epoch 41/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4140 - accuracy: 0.8101 - val_loss: 0.7387 - val_accuracy: 0.6167
# Epoch 42/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4307 - accuracy: 0.8228 - val_loss: 0.5414 - val_accuracy: 0.7500
# Epoch 43/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3600 - accuracy: 0.8650 - val_loss: 0.5616 - val_accuracy: 0.7333
# Epoch 44/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4016 - accuracy: 0.8143 - val_loss: 0.6161 - val_accuracy: 0.7000
# Epoch 45/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3760 - accuracy: 0.8439 - val_loss: 0.5704 - val_accuracy: 0.7667
# Epoch 46/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3670 - accuracy: 0.8481 - val_loss: 0.5446 - val_accuracy: 0.7500
# Epoch 47/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3447 - accuracy: 0.8608 - val_loss: 0.5599 - val_accuracy: 0.7667
# Epoch 48/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3450 - accuracy: 0.8861 - val_loss: 0.5985 - val_accuracy: 0.7500
# Epoch 49/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3869 - accuracy: 0.7890 - val_loss: 0.6162 - val_accuracy: 0.7500
# Epoch 50/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3661 - accuracy: 0.8312 - val_loss: 0.6112 - val_accuracy: 0.7333
# Epoch 51/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4324 - accuracy: 0.8228 - val_loss: 0.5520 - val_accuracy: 0.7667
# Epoch 52/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4127 - accuracy: 0.8143 - val_loss: 0.6025 - val_accuracy: 0.7167
# Epoch 53/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3808 - accuracy: 0.8565 - val_loss: 0.5842 - val_accuracy: 0.7500
# Epoch 54/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3595 - accuracy: 0.8523 - val_loss: 0.5725 - val_accuracy: 0.7333
# Epoch 55/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3386 - accuracy: 0.8565 - val_loss: 0.5534 - val_accuracy: 0.7667
# Epoch 56/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3475 - accuracy: 0.8186 - val_loss: 0.5765 - val_accuracy: 0.7833
# Epoch 57/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3373 - accuracy: 0.8523 - val_loss: 0.6184 - val_accuracy: 0.7500
# Epoch 58/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3583 - accuracy: 0.8397 - val_loss: 0.5982 - val_accuracy: 0.7500
# Epoch 59/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3231 - accuracy: 0.8819 - val_loss: 0.5634 - val_accuracy: 0.7833
# Epoch 60/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3126 - accuracy: 0.8650 - val_loss: 0.5707 - val_accuracy: 0.7833
# Epoch 61/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3628 - accuracy: 0.8397 - val_loss: 0.6383 - val_accuracy: 0.7167
# Epoch 62/100
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3248 - accuracy: 0.8650 - val_loss: 0.6257 - val_accuracy: 0.7333
# Epoch 63/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3710 - accuracy: 0.8186 - val_loss: 0.6134 - val_accuracy: 0.7333
# Epoch 64/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3123 - accuracy: 0.8734 - val_loss: 0.6343 - val_accuracy: 0.7500
# Epoch 65/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3277 - accuracy: 0.8481 - val_loss: 0.6026 - val_accuracy: 0.7333
# Epoch 66/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3215 - accuracy: 0.8692 - val_loss: 0.5751 - val_accuracy: 0.7667
# Epoch 67/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3103 - accuracy: 0.8692 - val_loss: 0.6373 - val_accuracy: 0.7167
# Epoch 68/100
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3358 - accuracy: 0.8481 - val_loss: 0.5991 - val_accuracy: 0.7833
# Epoch 69/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.2970 - accuracy: 0.8734 - val_loss: 0.6321 - val_accuracy: 0.7500
# Epoch 70/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3144 - accuracy: 0.8650 - val_loss: 0.6193 - val_accuracy: 0.7500
# Epoch 71/100
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3057 - accuracy: 0.8692 - val_loss: 0.6447 - val_accuracy: 0.7333
# Epoch 72/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3290 - accuracy: 0.8608 - val_loss: 0.6892 - val_accuracy: 0.7167
# Epoch 73/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3002 - accuracy: 0.8608 - val_loss: 0.6389 - val_accuracy: 0.7333
# Epoch 74/100
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3441 - accuracy: 0.8439 - val_loss: 0.6020 - val_accuracy: 0.7667
# Epoch 75/100
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3304 - accuracy: 0.8523 - val_loss: 0.6405 - val_accuracy: 0.7333
# Epoch 76/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3015 - accuracy: 0.8945 - val_loss: 0.6165 - val_accuracy: 0.7833
# Epoch 77/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3134 - accuracy: 0.8734 - val_loss: 0.6663 - val_accuracy: 0.7667
# Epoch 78/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3281 - accuracy: 0.8692 - val_loss: 0.6348 - val_accuracy: 0.7667
# Epoch 79/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2844 - accuracy: 0.8819 - val_loss: 0.6439 - val_accuracy: 0.7500
# Epoch 80/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3099 - accuracy: 0.8692 - val_loss: 0.6181 - val_accuracy: 0.7333
# Epoch 81/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.2952 - accuracy: 0.8776 - val_loss: 0.6383 - val_accuracy: 0.7500
# Epoch 82/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2786 - accuracy: 0.8734 - val_loss: 0.6556 - val_accuracy: 0.7500
# Epoch 83/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3207 - accuracy: 0.8608 - val_loss: 0.6389 - val_accuracy: 0.7667
# Epoch 84/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3031 - accuracy: 0.8734 - val_loss: 0.6301 - val_accuracy: 0.7667
# Epoch 85/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2912 - accuracy: 0.8608 - val_loss: 0.6170 - val_accuracy: 0.7833
# Epoch 86/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3288 - accuracy: 0.8397 - val_loss: 0.6900 - val_accuracy: 0.7333
# Epoch 87/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3031 - accuracy: 0.8861 - val_loss: 0.6747 - val_accuracy: 0.7667
# Epoch 88/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2836 - accuracy: 0.8734 - val_loss: 0.6504 - val_accuracy: 0.7667
# Epoch 89/100
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2895 - accuracy: 0.8776 - val_loss: 0.6912 - val_accuracy: 0.7167
# Epoch 90/100
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3448 - accuracy: 0.8228 - val_loss: 0.6203 - val_accuracy: 0.7667
# Epoch 91/100
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3036 - accuracy: 0.8734 - val_loss: 0.6889 - val_accuracy: 0.7167
# Epoch 92/100
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3143 - accuracy: 0.8608 - val_loss: 0.7307 - val_accuracy: 0.6500
# Epoch 93/100
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3691 - accuracy: 0.8312 - val_loss: 0.6143 - val_accuracy: 0.7667
# Epoch 94/100
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3197 - accuracy: 0.8565 - val_loss: 0.6231 - val_accuracy: 0.7333
# Epoch 95/100
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3309 - accuracy: 0.8397 - val_loss: 0.6245 - val_accuracy: 0.7667
# Epoch 96/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2832 - accuracy: 0.8734 - val_loss: 0.6708 - val_accuracy: 0.7167
# Epoch 97/100
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2928 - accuracy: 0.8608 - val_loss: 0.6089 - val_accuracy: 0.7667
# Epoch 98/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.2683 - accuracy: 0.9030 - val_loss: 0.6589 - val_accuracy: 0.7667
# Epoch 99/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2919 - accuracy: 0.8565 - val_loss: 0.6594 - val_accuracy: 0.7500
# Epoch 100/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2677 - accuracy: 0.8987 - val_loss: 0.6108 - val_accuracy: 0.7667

# %%
model.evaluate(test_ds)
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6108 - accuracy: 0.7667
# [0.610809326171875, 0.7666666507720947]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim((0, 1))
plt.legend(['train', 'test'], loc='upper left');

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
predictions = model.predict(test_ds)

# %%
bin_predictions = tf.round(predictions).numpy().flatten()

# %%
print(classification_report(y_test.values, bin_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.47      0.47        32
#            1       0.39      0.39      0.39        28
#
#     accuracy                           0.43        60
#    macro avg       0.43      0.43      0.43        60
# weighted avg       0.43      0.43      0.43        60

# %%
cnf_matrix = confusion_matrix(y_test, bin_predictions)
cnf_matrix
# Out:
# array([[15, 17],
#        [17, 11]])

# %%
class_names = [0,1]
fig,ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

sns.heatmap(pd.DataFrame(cnf_matrix),annot=True,cmap="Blues",fmt="d",cbar=False)
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.ylabel('Actual label')
plt.xlabel('Predicted label');
